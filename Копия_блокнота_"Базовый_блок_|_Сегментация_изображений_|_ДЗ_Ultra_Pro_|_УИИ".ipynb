# %% [markdown]
# <a href="https://colab.research.google.com/github/Mervvick/AI_ImageSegmentation_UltraPro/blob/main/%D0%9A%D0%BE%D0%BF%D0%B8%D1%8F_%D0%B1%D0%BB%D0%BE%D0%BA%D0%BD%D0%BE%D1%82%D0%B0_%22%D0%91%D0%B0%D0%B7%D0%BE%D0%B2%D1%8B%D0%B9_%D0%B1%D0%BB%D0%BE%D0%BA_%7C_%D0%A1%D0%B5%D0%B3%D0%BC%D0%B5%D0%BD%D1%82%D0%B0%D1%86%D0%B8%D1%8F_%D0%B8%D0%B7%D0%BE%D0%B1%D1%80%D0%B0%D0%B6%D0%B5%D0%BD%D0%B8%D0%B9_%7C_%D0%94%D0%97_Ultra_Pro_%7C_%D0%A3%D0%98%D0%98%22.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 1. На основе учебного ноутбука, проведите финальную подготовку данных. измените количество сегментирующих классов с `16` на `7`
#  - 0_класс - FLOOR
#  - 1_класс - CEILING
#  - 2_класс - WALL
#  - 3_класс - APERTURE, DOOR, WINDOW
#  - 4_класс - COLUMN, RAILINGS, LADDER
#  - 5_класс - INVENTORY
#  - 6_класс - LAMP, WIRE, BEAM, EXTERNAL, BATTERY,
# PEOPLE
#
# 2. Реализуйте сегментацию базы Стройка на основе модели `PSPnet`. Статья для изучения [Pyramid Scene Parsing Network](https://hszhao.github.io/projects/pspnet/) .
#
#
# **Важно!**
#
# Многие эксперименты могут приводить к переполнению ОЗУ в вашем ноутбуке и сброса кода обучения.
#
# ![image.png](data:image/png;base64,...)
#
#
# Для предотвращения переполнения ОЗУ может помочь библиотека `gc`. Вставьте строчку `gc.collect()` в цикл ваших экспериментов для сбора и удаления временных данных (кеш).

# %% [markdown]
# Перед выполнением задания, пожалуйста, запустите ячейку `Подготовка` ниже:

# %% [markdown]
# ## Подготовка

# %% [markdown]
# ### Импорт библиотек

# %%
 # Импортируем модели keras: Model
from tensorflow.keras.models import Model

 # Импортируем стандартные слои keras
from tensorflow.keras.layers import Input, Conv2DTranspose, concatenate, Activation
from tensorflow.keras.layers import MaxPooling2D, Conv2D, BatchNormalization, UpSampling2D

# Импортируем оптимизатор Adam
from tensorflow.keras.optimizers import Adam

from tensorflow.keras.callbacks import ReduceLROnPlateau

# Импортируем модуль pyplot библиотеки matplotlib для построения графиков
import matplotlib.pyplot as plt

# Импортируем модуль image для работы с изображениями
from tensorflow.keras.preprocessing import image

# Импортируем библиотеку numpy
import numpy as np

# Импортируем методделения выборки
from sklearn.model_selection import train_test_split

# загрузка файлов по HTML ссылке
import gdown

# Для работы с файлами
import os

# Для генерации случайных чисел
import random

import time

# импортируем модель Image для работы с изображениями
from PIL import Image

# очистка ОЗУ
import gc

# %% [markdown]
# ### Загрузка датасета
#
# грузим и распаковываем архив картинок

# %%
# Загрузка датасета из облака

gdown.download('https://storage.yandexcloud.net/aiueducation/Content/base/l14/construction_256x192.zip', None, quiet=False)
#gdown.download('https://storage.yandexcloud.net/aiueducation/Content/base/l14/construction_512x384.zip', None, quiet=False)

# !unzip -q 'construction_256x192.zip' # распоковываем архив
# Out:
# Downloading...
# From: https://storage.yandexcloud.net/aiueducation/Content/base/l14/construction_256x192.zip
# To: /content/construction_256x192.zip
# 100%|██████████| 214M/214M [00:13<00:00, 15.8MB/s]

# %% [markdown]
# ## Решение

# %%
# Ваше решение

IMG_WIDTH = 192               # Ширина картинки
IMG_HEIGHT = 256             # Высота картинки
NUM_CLASSES = 16              # Задаем количество классов на изображении
TRAIN_DIRECTORY = 'train'     # Название папки с файлами обучающей выборки
VAL_DIRECTORY = 'val'         # Название папки с файлами проверочной выборки

# %%
train_images = [] # Создаем пустой список для хранений оригинальных изображений обучающей выборки
val_images = [] # Создаем пустой список для хранений оригинальных изображений проверочной выборки

cur_time = time.time()  # Засекаем текущее время

# Проходим по всем файлам в каталоге по указанному пути
for filename in sorted(os.listdir(TRAIN_DIRECTORY+'/original')):
    # Читаем очередную картинку и добавляем ее в список изображений с указанным target_size
    train_images.append(image.load_img(os.path.join(TRAIN_DIRECTORY+'/original',filename),
                                       target_size=(IMG_WIDTH, IMG_HEIGHT)))

# Отображаем время загрузки картинок обучающей выборки
print ('Обучающая выборка загружена. Время загрузки: ', round(time.time() - cur_time, 2), 'c', sep='')

# Отображаем количество элементов в обучающей выборке
print ('Количество изображений: ', len(train_images))

cur_time = time.time() # Засекаем текущее время

# Проходим по всем файлам в каталоге по указанному пути
for filename in sorted(os.listdir(VAL_DIRECTORY+'/original')):
    # Читаем очередную картинку и добавляем ее в список изображений с указанным target_size
    val_images.append(image.load_img(os.path.join(VAL_DIRECTORY+'/original',filename),
                                     target_size=(IMG_WIDTH, IMG_HEIGHT)))

# Отображаем время загрузки картинок проверочной выборки
print ('Проверочная выборка загружена. Время загрузки: ', round(time.time() - cur_time, 2), 'c', sep='')

# Отображаем количество элементов в проверочной выборке
print ('Количество изображений: ', len(val_images))
# Out:
# Обучающая выборка загружена. Время загрузки: 0.27c
# Количество изображений:  1900
# Проверочная выборка загружена. Время загрузки: 0.01c
# Количество изображений:  100

# %%
train_segments = [] # Создаем пустой список для хранений оригинальных изображений обучающей выборки
val_segments = [] # Создаем пустой список для хранений оригинальных изображений проверочной выборки

cur_time = time.time() # Засекаем текущее время

for filename in sorted(os.listdir(TRAIN_DIRECTORY+'/segment')): # Проходим по всем файлам в каталоге по указанному пути
    # Читаем очередную картинку и добавляем ее в список изображений с указанным target_size
    train_segments.append(image.load_img(os.path.join(TRAIN_DIRECTORY+'/segment',filename),
                                       target_size=(IMG_WIDTH, IMG_HEIGHT)))

# Отображаем время загрузки картинок обучающей выборки
print ('Обучающая выборка загружена. Время загрузки: ', round(time.time() - cur_time, 2), 'c', sep='')

# Отображаем количество элементов в обучающем наборе сегментированных изображений
print ('Количество изображений: ', len(train_segments))

cur_time = time.time() # Засекаем текущее время

for filename in sorted(os.listdir(VAL_DIRECTORY+'/segment')): # Проходим по всем файлам в каталоге по указанному пути
    # Читаем очередную картинку и добавляем ее в список изображений с указанным target_size
    val_segments.append(image.load_img(os.path.join(VAL_DIRECTORY+'/segment',filename),
                                     target_size=(IMG_WIDTH, IMG_HEIGHT)))

# Отображаем время загрузки картинок проверочной выборки
print ('Проверочная выборка загружена. Время загрузки: ', round(time.time() - cur_time, 2), 'c', sep='')

# Отображаем количество элементов в проверочном наборе сегментированных изображений
print ('Количество изображений: ', len(val_segments))
# Out:
# Обучающая выборка загружена. Время загрузки: 0.26c
# Количество изображений:  1900
# Проверочная выборка загружена. Время загрузки: 0.01c
# Количество изображений:  100

# %%
# Ваше решение
FLOOR = (100, 100, 100)
CEILING = (0, 0, 100)
WALL = (0, 100, 0)
COLUMN = (100, 0, 0)
APERTURE = (0, 100, 100)
DOOR = (100, 0, 100)
WINDOW = (100, 100, 0)
EXTERNAL = (200, 200, 200)
RAILINGS = (0, 200, 0)
BATTERY = (200, 0, 0)
PEOPLE = (0, 200, 200)
LADDER = (0, 0, 200)
INVENTORY = (200, 0, 200)
LAMP = (200, 200, 0)
WIRE = (0, 100, 200)
BEAM = (100, 0, 200)

# %%
CLASS_LABELS = (FLOOR, CEILING, WALL, COLUMN, APERTURE, DOOR, WINDOW, EXTERNAL, RAILINGS, BATTERY, PEOPLE, LADDER, INVENTORY, LAMP, WIRE, BEAM)

# %%
def rgb_to_labels(image_list):

    result = []

    for d in image_list:
        sample = np.array(d)
        y = np.zeros((IMG_WIDTH, IMG_HEIGHT, 1), dtype='uint8')

        for i, cl in enumerate(CLASS_LABELS):
            y[np.where(np.all(sample == CLASS_LABELS[i], axis=-1))] = i

        result.append(y)

    return np.array(result)

# %%
def labels_to_rgb(image_list):

    result = []
    for y in image_list:
        temp = np.zeros((IMG_WIDTH, IMG_HEIGHT, 3), dtype='uint8')
        for i, cl in enumerate(CLASS_LABELS):
            temp[np.where(np.all(y==i, axis=-1))] = CLASS_LABELS[i]
        result.append(temp)

    return np.array(result)

# %%
x_train = []
x_val = []

for img in train_images:
  x_train.append(image.img_to_array(img))
x_train = np.array(x_train)

for img in val_images:
  x_val.append(image.img_to_array(img))
x_val = np.array(x_val)

print(x_train.shape)
print(x_val.shape)
# Out:
# (1900, 192, 256, 3)
# (100, 192, 256, 3)

# %%
y_train = []
y_val = []

y_train = rgb_to_labels(train_segments)
y_val = rgb_to_labels(val_segments)

print(y_train.shape)
print(y_val.shape)
# Out:
# (1900, 192, 256, 1)
# (100, 192, 256, 1)

# %%
y_train_7 = y_train.copy()
y_val_7 = y_val.copy()

mask = [[FLOOR],
        [CEILING],
        [WALL],
        [APERTURE, DOOR, WINDOW],
        [COLUMN, RAILINGS, LADDER],
        [INVENTORY],
        [LAMP, WIRE, BEAM, EXTERNAL, BATTERY, PEOPLE]]

print(y_train.max())
print(y_val.max())

for x, m in enumerate(mask):
  for cl in m:
    y_train_7[y_train == CLASS_LABELS.index(cl)] = x
    y_val_7[y_val == CLASS_LABELS.index(cl)] = x

print(y_train_7.max())
print(y_val_7.max())
# Out:
# 15
# 15
# 6
# 6

# %% [markdown]
# ## Модель

# %%
NUM_CLASSES = 7
INPUT_SHAPE = (IMG_WIDTH, IMG_HEIGHT, 3)
NUM_BLOCKS = 3

# %%
def create_model(input_shape = INPUT_SHAPE,
                 num_classes = NUM_CLASSES,
                 num_blocks = NUM_BLOCKS):

    input = Input(input_shape)

    x = Conv2D(32, (3,3), padding = 'same')(input)
    x = BatchNormalization()(x)
    conv1_out = Activation('relu')(x)

    blocks_list = []
    blocks_list.append(conv1_out)

    for i in range(1, num_blocks + 1):
      block = MaxPooling2D(2**i)(conv1_out)
      block = Conv2D(32, (3, 3), padding = 'same')(block)
      block = BatchNormalization()(block)
      block = Activation('relu')(block)
      block_out = Conv2DTranspose(32, (3, 3), strides = 2**i, padding = 'same')(block)
      blocks_list.append(block_out)

    x = concatenate(blocks_list)
    x = Conv2D(32, (3, 3), padding = 'same')(x)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)

    x = Conv2D(32, (3, 3), padding = 'same')(x)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)

    output = Conv2D(num_classes, (1, 1), activation = 'softmax', padding = 'same')(x)

    model = Model(input, output)

    return model

# %%
callback = ReduceLROnPlateau(monitor = 'val_sparse_categorical_accuracy',
                             factor = 0.1,
                             patience = 5,
                             verbose = 1)

# %%
gc.collect()
model = create_model()
model.compile(optimizer = Adam(0.001),
              loss = 'sparse_categorical_crossentropy',
              metrics = ['sparse_categorical_accuracy'])

history = model.fit(x_train,
                    y_train_7,
                    batch_size = 32,
                    epochs = 50,
                    verbose = 1,
                    callbacks = [callback],
                    validation_data = (x_val, y_val_7))
# Out:
# Epoch 1/50
# 60/60 [==============================] - 23s 295ms/step - loss: 1.7075 - sparse_categorical_accuracy: 0.3723 - val_loss: 3.3687 - val_sparse_categorical_accuracy: 0.1250 - lr: 0.0010
# Epoch 2/50
# 60/60 [==============================] - 17s 291ms/step - loss: 1.2315 - sparse_categorical_accuracy: 0.5913 - val_loss: 1.8403 - val_sparse_categorical_accuracy: 0.3728 - lr: 0.0010
# Epoch 3/50
# 60/60 [==============================] - 17s 287ms/step - loss: 1.1094 - sparse_categorical_accuracy: 0.6215 - val_loss: 1.6010 - val_sparse_categorical_accuracy: 0.4478 - lr: 0.0010
# Epoch 4/50
# 60/60 [==============================] - 18s 293ms/step - loss: 1.0599 - sparse_categorical_accuracy: 0.6357 - val_loss: 1.7617 - val_sparse_categorical_accuracy: 0.4072 - lr: 0.0010
# Epoch 5/50
# 60/60 [==============================] - 18s 294ms/step - loss: 1.0423 - sparse_categorical_accuracy: 0.6402 - val_loss: 1.4718 - val_sparse_categorical_accuracy: 0.4896 - lr: 0.0010
# Epoch 6/50
# 60/60 [==============================] - 18s 295ms/step - loss: 1.0135 - sparse_categorical_accuracy: 0.6516 - val_loss: 1.4288 - val_sparse_categorical_accuracy: 0.5121 - lr: 0.0010
# Epoch 7/50
# 60/60 [==============================] - 18s 296ms/step - loss: 1.0026 - sparse_categorical_accuracy: 0.6552 - val_loss: 1.4376 - val_sparse_categorical_accuracy: 0.4717 - lr: 0.0010
# Epoch 8/50
# 60/60 [==============================] - 18s 292ms/step - loss: 0.9940 - sparse_categorical_accuracy: 0.6564 - val_loss: 1.4320 - val_sparse_categorical_accuracy: 0.4659 - lr: 0.0010
# Epoch 9/50
# 60/60 [==============================] - 18s 298ms/step - loss: 0.9799 - sparse_categorical_accuracy: 0.6615 - val_loss: 1.3749 - val_sparse_categorical_accuracy: 0.5114 - lr: 0.0010
# Epoch 10/50
# 60/60 [==============================] - 18s 298ms/step - loss: 0.9656 - sparse_categorical_accuracy: 0.6668 - val_loss: 1.6783 - val_sparse_categorical_accuracy: 0.4828 - lr: 0.0010
# Epoch 11/50
# 60/60 [==============================] - 18s 293ms/step - loss: 0.9729 - sparse_categorical_accuracy: 0.6635 - val_loss: 1.3915 - val_sparse_categorical_accuracy: 0.5275 - lr: 0.0010
# Epoch 12/50
# 60/60 [==============================] - 18s 294ms/step - loss: 0.9612 - sparse_categorical_accuracy: 0.6678 - val_loss: 1.3661 - val_sparse_categorical_accuracy: 0.5100 - lr: 0.0010
# Epoch 13/50
# 60/60 [==============================] - 18s 300ms/step - loss: 0.9571 - sparse_categorical_accuracy: 0.6695 - val_loss: 1.4749 - val_sparse_categorical_accuracy: 0.4340 - lr: 0.0010
# Epoch 14/50
# 60/60 [==============================] - 18s 294ms/step - loss: 0.9408 - sparse_categorical_accuracy: 0.6752 - val_loss: 1.3965 - val_sparse_categorical_accuracy: 0.5301 - lr: 0.0010
# Epoch 15/50
# 60/60 [==============================] - 18s 296ms/step - loss: 0.9399 - sparse_categorical_accuracy: 0.6759 - val_loss: 1.3680 - val_sparse_categorical_accuracy: 0.5277 - lr: 0.0010
# Epoch 16/50
# 60/60 [==============================] - 18s 295ms/step - loss: 0.9315 - sparse_categorical_accuracy: 0.6794 - val_loss: 1.3573 - val_sparse_categorical_accuracy: 0.5365 - lr: 0.0010
# Epoch 17/50
# 60/60 [==============================] - 18s 297ms/step - loss: 0.9353 - sparse_categorical_accuracy: 0.6768 - val_loss: 1.3046 - val_sparse_categorical_accuracy: 0.5381 - lr: 0.0010
# Epoch 18/50
# 60/60 [==============================] - 18s 297ms/step - loss: 0.9247 - sparse_categorical_accuracy: 0.6806 - val_loss: 1.3352 - val_sparse_categorical_accuracy: 0.5316 - lr: 0.0010
# Epoch 19/50
# 60/60 [==============================] - 18s 302ms/step - loss: 0.9204 - sparse_categorical_accuracy: 0.6814 - val_loss: 1.3719 - val_sparse_categorical_accuracy: 0.5027 - lr: 0.0010
# Epoch 20/50
# 60/60 [==============================] - 18s 296ms/step - loss: 0.9165 - sparse_categorical_accuracy: 0.6840 - val_loss: 1.2933 - val_sparse_categorical_accuracy: 0.5545 - lr: 0.0010
# Epoch 21/50
# 60/60 [==============================] - 18s 302ms/step - loss: 0.9130 - sparse_categorical_accuracy: 0.6839 - val_loss: 1.2984 - val_sparse_categorical_accuracy: 0.5555 - lr: 0.0010
# Epoch 22/50
# 60/60 [==============================] - 18s 297ms/step - loss: 0.9137 - sparse_categorical_accuracy: 0.6847 - val_loss: 1.2978 - val_sparse_categorical_accuracy: 0.5573 - lr: 0.0010
# Epoch 23/50
# 60/60 [==============================] - 18s 297ms/step - loss: 0.9087 - sparse_categorical_accuracy: 0.6843 - val_loss: 1.4225 - val_sparse_categorical_accuracy: 0.5295 - lr: 0.0010
# Epoch 24/50
# 60/60 [==============================] - 18s 297ms/step - loss: 0.8959 - sparse_categorical_accuracy: 0.6896 - val_loss: 1.3116 - val_sparse_categorical_accuracy: 0.5407 - lr: 0.0010
# Epoch 25/50
# 60/60 [==============================] - 18s 301ms/step - loss: 0.9100 - sparse_categorical_accuracy: 0.6839 - val_loss: 1.3313 - val_sparse_categorical_accuracy: 0.5462 - lr: 0.0010
# Epoch 26/50
# 60/60 [==============================] - 18s 295ms/step - loss: 0.8965 - sparse_categorical_accuracy: 0.6893 - val_loss: 1.3003 - val_sparse_categorical_accuracy: 0.5511 - lr: 0.0010
# Epoch 27/50
# 60/60 [==============================] - ETA: 0s - loss: 0.9000 - sparse_categorical_accuracy: 0.6876
# Epoch 27: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# 60/60 [==============================] - 18s 296ms/step - loss: 0.9000 - sparse_categorical_accuracy: 0.6876 - val_loss: 1.2961 - val_sparse_categorical_accuracy: 0.5381 - lr: 0.0010
# Epoch 28/50
# 60/60 [==============================] - 18s 296ms/step - loss: 0.8714 - sparse_categorical_accuracy: 0.6987 - val_loss: 1.2319 - val_sparse_categorical_accuracy: 0.5726 - lr: 1.0000e-04
# Epoch 29/50
# 60/60 [==============================] - 18s 296ms/step - loss: 0.8633 - sparse_categorical_accuracy: 0.7026 - val_loss: 1.2400 - val_sparse_categorical_accuracy: 0.5708 - lr: 1.0000e-04
# Epoch 30/50
# 60/60 [==============================] - 18s 301ms/step - loss: 0.8629 - sparse_categorical_accuracy: 0.7023 - val_loss: 1.2466 - val_sparse_categorical_accuracy: 0.5709 - lr: 1.0000e-04
# Epoch 31/50
# 60/60 [==============================] - 18s 302ms/step - loss: 0.8625 - sparse_categorical_accuracy: 0.7023 - val_loss: 1.2445 - val_sparse_categorical_accuracy: 0.5730 - lr: 1.0000e-04
# Epoch 32/50
# 60/60 [==============================] - 18s 301ms/step - loss: 0.8622 - sparse_categorical_accuracy: 0.7031 - val_loss: 1.2411 - val_sparse_categorical_accuracy: 0.5737 - lr: 1.0000e-04
# Epoch 33/50
# 60/60 [==============================] - 18s 296ms/step - loss: 0.8586 - sparse_categorical_accuracy: 0.7042 - val_loss: 1.2531 - val_sparse_categorical_accuracy: 0.5695 - lr: 1.0000e-04
# Epoch 34/50
# 60/60 [==============================] - 18s 296ms/step - loss: 0.8584 - sparse_categorical_accuracy: 0.7041 - val_loss: 1.2390 - val_sparse_categorical_accuracy: 0.5730 - lr: 1.0000e-04
# Epoch 35/50
# 60/60 [==============================] - 18s 301ms/step - loss: 0.8564 - sparse_categorical_accuracy: 0.7049 - val_loss: 1.2543 - val_sparse_categorical_accuracy: 0.5692 - lr: 1.0000e-04
# Epoch 36/50
# 60/60 [==============================] - 18s 295ms/step - loss: 0.8573 - sparse_categorical_accuracy: 0.7047 - val_loss: 1.2381 - val_sparse_categorical_accuracy: 0.5753 - lr: 1.0000e-04
# Epoch 37/50
# 60/60 [==============================] - 18s 301ms/step - loss: 0.8551 - sparse_categorical_accuracy: 0.7050 - val_loss: 1.2359 - val_sparse_categorical_accuracy: 0.5756 - lr: 1.0000e-04
# Epoch 38/50
# 60/60 [==============================] - 18s 300ms/step - loss: 0.8556 - sparse_categorical_accuracy: 0.7047 - val_loss: 1.2471 - val_sparse_categorical_accuracy: 0.5708 - lr: 1.0000e-04
# Epoch 39/50
# 60/60 [==============================] - 18s 302ms/step - loss: 0.8523 - sparse_categorical_accuracy: 0.7056 - val_loss: 1.2693 - val_sparse_categorical_accuracy: 0.5620 - lr: 1.0000e-04
# Epoch 40/50
# 60/60 [==============================] - 18s 301ms/step - loss: 0.8550 - sparse_categorical_accuracy: 0.7052 - val_loss: 1.2508 - val_sparse_categorical_accuracy: 0.5720 - lr: 1.0000e-04
# Epoch 41/50
# 60/60 [==============================] - 18s 300ms/step - loss: 0.8543 - sparse_categorical_accuracy: 0.7053 - val_loss: 1.2391 - val_sparse_categorical_accuracy: 0.5759 - lr: 1.0000e-04
# Epoch 42/50
# 60/60 [==============================] - 18s 296ms/step - loss: 0.8565 - sparse_categorical_accuracy: 0.7041 - val_loss: 1.2386 - val_sparse_categorical_accuracy: 0.5761 - lr: 1.0000e-04
# Epoch 43/50
# 60/60 [==============================] - 18s 297ms/step - loss: 0.8496 - sparse_categorical_accuracy: 0.7072 - val_loss: 1.2477 - val_sparse_categorical_accuracy: 0.5783 - lr: 1.0000e-04
# Epoch 44/50
# 60/60 [==============================] - 18s 303ms/step - loss: 0.8546 - sparse_categorical_accuracy: 0.7050 - val_loss: 1.2664 - val_sparse_categorical_accuracy: 0.5708 - lr: 1.0000e-04
# Epoch 45/50
# 60/60 [==============================] - 18s 297ms/step - loss: 0.8524 - sparse_categorical_accuracy: 0.7059 - val_loss: 1.2445 - val_sparse_categorical_accuracy: 0.5760 - lr: 1.0000e-04
# Epoch 46/50
# 60/60 [==============================] - 18s 303ms/step - loss: 0.8504 - sparse_categorical_accuracy: 0.7070 - val_loss: 1.2382 - val_sparse_categorical_accuracy: 0.5748 - lr: 1.0000e-04
# Epoch 47/50
# 60/60 [==============================] - 18s 296ms/step - loss: 0.8520 - sparse_categorical_accuracy: 0.7066 - val_loss: 1.2300 - val_sparse_categorical_accuracy: 0.5770 - lr: 1.0000e-04
# Epoch 48/50
# 60/60 [==============================] - ETA: 0s - loss: 0.8486 - sparse_categorical_accuracy: 0.7070
# Epoch 48: ReduceLROnPlateau reducing learning rate to 1.0000000474974514e-05.
# 60/60 [==============================] - 18s 302ms/step - loss: 0.8486 - sparse_categorical_accuracy: 0.7070 - val_loss: 1.2409 - val_sparse_categorical_accuracy: 0.5719 - lr: 1.0000e-04
# Epoch 49/50
# 60/60 [==============================] - 18s 301ms/step - loss: 0.8454 - sparse_categorical_accuracy: 0.7085 - val_loss: 1.2393 - val_sparse_categorical_accuracy: 0.5761 - lr: 1.0000e-05
# Epoch 50/50
# 60/60 [==============================] - 18s 301ms/step - loss: 0.8461 - sparse_categorical_accuracy: 0.7089 - val_loss: 1.2380 - val_sparse_categorical_accuracy: 0.5768 - lr: 1.0000e-05

# %%
plt.figure(figsize=(10,4))
plt.plot(history.history['sparse_categorical_accuracy'])
plt.plot(history.history['val_sparse_categorical_accuracy'])
plt.show()

# %%
def process_images(model,        # обученная модель
                   count = 1     # количество случайных картинок для сегментации
                   ):

    # Генерация случайного списка индексов в количестве count между (0, len(x_val)
    indexes = np.random.randint(0, len(x_val), count)

    # Вычисление предсказания сети для картинок с отобранными индексами
    predict = np.argmax(model.predict(x_val[indexes]), axis=-1)

    # Подготовка цветов классов для отрисовки предсказания
    orig = labels_to_rgb(predict[..., None])
    fig, axs = plt.subplots(3, count, figsize=(25, 15))

    # Отрисовка результата работы модели
    for i in range(count):
        # Отображение на графике в первой линии предсказания модели
        axs[0, 0].set_title('Результат работы модели:')
        axs[0, i].imshow(orig[i])
        axs[0, i].axis('off')

        # Отображение на графике во второй линии сегментированного изображения из y_val
        axs[1, 0].set_title('Оригинальное сегментированное')
        axs[1, i].imshow(val_segments[indexes[i]])
        axs[1 ,i].axis('off')

        # Отображение на графике в третьей линии оригинального изображения
        axs[2, 0].set_title('Оригинальное изображение')
        axs[2, i].imshow(val_images[indexes[i]])
        axs[2 ,i].axis('off')

    plt.show()

# %%
process_images(model, 5)
# Out:
# 1/1 [==============================] - 1s 1s/step

# %% [markdown]
# ## Модель №2

# %%
NUM_CLASSES = 7
INPUT_SHAPE = (IMG_WIDTH, IMG_HEIGHT, 3)
NUM_BLOCKS = 4 ##

# %%
def create_model2(input_shape = INPUT_SHAPE,
                 num_classes = NUM_CLASSES,
                 num_blocks = NUM_BLOCKS):

    input = Input(input_shape)

    x = Conv2D(32, (3,3), padding = 'same')(input)
    x = BatchNormalization()(x)
    conv1_out = Activation('relu')(x)

    blocks_list = []
    blocks_list.append(conv1_out)

    for i in range(1, num_blocks + 1):
      block = MaxPooling2D(2**i)(conv1_out)
      block = Conv2D(32, (2, 2), padding = 'same')(block)
      block = BatchNormalization()(block)
      block = Activation('relu')(block)
      block_out = Conv2DTranspose(32, (3, 3), strides = 2**i, padding = 'same')(block)
      blocks_list.append(block_out)

    x = concatenate(blocks_list)
    x = Conv2D(32, (3, 3), padding = 'same')(x)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)

    x = Conv2D(32, (3, 3), padding = 'same')(x)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)

    output = Conv2D(num_classes, (2, 2), activation = 'softmax', padding = 'same')(x) ##

    model = Model(input, output)

    return model

# %%
gc.collect()
model = create_model2()
model.compile(optimizer = Adam(0.001),
              loss = 'sparse_categorical_crossentropy',
              metrics = ['sparse_categorical_accuracy'])

history = model.fit(x_train,
                    y_train_7,
                    batch_size = 32,
                    epochs = 50,
                    verbose = 1,
                    callbacks = [callback],
                    validation_data = (x_val, y_val_7))

plt.figure(figsize=(10,4))
plt.plot(history.history['sparse_categorical_accuracy'])
plt.plot(history.history['val_sparse_categorical_accuracy'])
plt.show()
# Out:
# Epoch 1/50
# 60/60 [==============================] - 27s 338ms/step - loss: 1.5717 - sparse_categorical_accuracy: 0.4305 - val_loss: 2.6494 - val_sparse_categorical_accuracy: 0.1519 - lr: 0.0010
# Epoch 2/50
# 60/60 [==============================] - 20s 327ms/step - loss: 1.1919 - sparse_categorical_accuracy: 0.5879 - val_loss: 1.8960 - val_sparse_categorical_accuracy: 0.3270 - lr: 0.0010
# Epoch 3/50
# 60/60 [==============================] - 20s 330ms/step - loss: 1.1256 - sparse_categorical_accuracy: 0.6102 - val_loss: 1.5767 - val_sparse_categorical_accuracy: 0.4549 - lr: 0.0010
# Epoch 4/50
# 60/60 [==============================] - 20s 331ms/step - loss: 1.0800 - sparse_categorical_accuracy: 0.6276 - val_loss: 1.4827 - val_sparse_categorical_accuracy: 0.4927 - lr: 0.0010
# Epoch 5/50
# 60/60 [==============================] - 20s 337ms/step - loss: 1.0546 - sparse_categorical_accuracy: 0.6349 - val_loss: 1.3692 - val_sparse_categorical_accuracy: 0.5323 - lr: 0.0010
# Epoch 6/50
# 60/60 [==============================] - 20s 336ms/step - loss: 1.0416 - sparse_categorical_accuracy: 0.6407 - val_loss: 1.3987 - val_sparse_categorical_accuracy: 0.5253 - lr: 0.0010
# Epoch 7/50
# 60/60 [==============================] - 20s 338ms/step - loss: 1.0225 - sparse_categorical_accuracy: 0.6461 - val_loss: 1.3738 - val_sparse_categorical_accuracy: 0.5227 - lr: 0.0010
# Epoch 8/50
# 60/60 [==============================] - 20s 338ms/step - loss: 1.0187 - sparse_categorical_accuracy: 0.6474 - val_loss: 1.4223 - val_sparse_categorical_accuracy: 0.5244 - lr: 0.0010
# Epoch 9/50
# 60/60 [==============================] - 20s 340ms/step - loss: 1.0092 - sparse_categorical_accuracy: 0.6492 - val_loss: 1.3778 - val_sparse_categorical_accuracy: 0.5346 - lr: 0.0010
# Epoch 10/50
# 60/60 [==============================] - 21s 345ms/step - loss: 0.9941 - sparse_categorical_accuracy: 0.6556 - val_loss: 1.3820 - val_sparse_categorical_accuracy: 0.5345 - lr: 0.0010
# Epoch 11/50
# 60/60 [==============================] - 20s 341ms/step - loss: 0.9868 - sparse_categorical_accuracy: 0.6580 - val_loss: 1.3465 - val_sparse_categorical_accuracy: 0.5324 - lr: 0.0010
# Epoch 12/50
# 60/60 [==============================] - 21s 347ms/step - loss: 0.9776 - sparse_categorical_accuracy: 0.6617 - val_loss: 1.4467 - val_sparse_categorical_accuracy: 0.5114 - lr: 0.0010
# Epoch 13/50
# 60/60 [==============================] - 21s 344ms/step - loss: 0.9761 - sparse_categorical_accuracy: 0.6609 - val_loss: 1.3771 - val_sparse_categorical_accuracy: 0.5242 - lr: 0.0010
# Epoch 14/50
# 60/60 [==============================] - 21s 349ms/step - loss: 0.9691 - sparse_categorical_accuracy: 0.6640 - val_loss: 1.2993 - val_sparse_categorical_accuracy: 0.5453 - lr: 0.0010
# Epoch 15/50
# 60/60 [==============================] - 21s 346ms/step - loss: 0.9631 - sparse_categorical_accuracy: 0.6670 - val_loss: 1.3505 - val_sparse_categorical_accuracy: 0.5249 - lr: 0.0010
# Epoch 16/50
# 60/60 [==============================] - 21s 345ms/step - loss: 0.9466 - sparse_categorical_accuracy: 0.6724 - val_loss: 1.3472 - val_sparse_categorical_accuracy: 0.5285 - lr: 0.0010
# Epoch 17/50
# 60/60 [==============================] - 21s 350ms/step - loss: 0.9462 - sparse_categorical_accuracy: 0.6739 - val_loss: 1.3290 - val_sparse_categorical_accuracy: 0.5382 - lr: 0.0010
# Epoch 18/50
# 60/60 [==============================] - 21s 349ms/step - loss: 0.9547 - sparse_categorical_accuracy: 0.6696 - val_loss: 1.3343 - val_sparse_categorical_accuracy: 0.5419 - lr: 0.0010
# Epoch 19/50
# 60/60 [==============================] - ETA: 0s - loss: 0.9413 - sparse_categorical_accuracy: 0.6733
# Epoch 19: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# 60/60 [==============================] - 21s 350ms/step - loss: 0.9413 - sparse_categorical_accuracy: 0.6733 - val_loss: 1.3431 - val_sparse_categorical_accuracy: 0.5420 - lr: 0.0010
# Epoch 20/50
# 60/60 [==============================] - 21s 353ms/step - loss: 0.9175 - sparse_categorical_accuracy: 0.6827 - val_loss: 1.2819 - val_sparse_categorical_accuracy: 0.5572 - lr: 1.0000e-04
# Epoch 21/50
# 60/60 [==============================] - 21s 353ms/step - loss: 0.9121 - sparse_categorical_accuracy: 0.6858 - val_loss: 1.2875 - val_sparse_categorical_accuracy: 0.5556 - lr: 1.0000e-04
# Epoch 22/50
# 60/60 [==============================] - 21s 348ms/step - loss: 0.9048 - sparse_categorical_accuracy: 0.6870 - val_loss: 1.2724 - val_sparse_categorical_accuracy: 0.5614 - lr: 1.0000e-04
# Epoch 23/50
# 60/60 [==============================] - 21s 352ms/step - loss: 0.9058 - sparse_categorical_accuracy: 0.6871 - val_loss: 1.2821 - val_sparse_categorical_accuracy: 0.5585 - lr: 1.0000e-04
# Epoch 24/50
# 60/60 [==============================] - 21s 352ms/step - loss: 0.9041 - sparse_categorical_accuracy: 0.6884 - val_loss: 1.2709 - val_sparse_categorical_accuracy: 0.5617 - lr: 1.0000e-04
# Epoch 25/50
# 60/60 [==============================] - 21s 349ms/step - loss: 0.9028 - sparse_categorical_accuracy: 0.6889 - val_loss: 1.2686 - val_sparse_categorical_accuracy: 0.5631 - lr: 1.0000e-04
# Epoch 26/50
# 60/60 [==============================] - 21s 348ms/step - loss: 0.9055 - sparse_categorical_accuracy: 0.6878 - val_loss: 1.2693 - val_sparse_categorical_accuracy: 0.5616 - lr: 1.0000e-04
# Epoch 27/50
# 60/60 [==============================] - 21s 352ms/step - loss: 0.9028 - sparse_categorical_accuracy: 0.6893 - val_loss: 1.2732 - val_sparse_categorical_accuracy: 0.5596 - lr: 1.0000e-04
# Epoch 28/50
# 60/60 [==============================] - 21s 352ms/step - loss: 0.9005 - sparse_categorical_accuracy: 0.6898 - val_loss: 1.2791 - val_sparse_categorical_accuracy: 0.5608 - lr: 1.0000e-04
# Epoch 29/50
# 60/60 [==============================] - 21s 351ms/step - loss: 0.8993 - sparse_categorical_accuracy: 0.6899 - val_loss: 1.2830 - val_sparse_categorical_accuracy: 0.5596 - lr: 1.0000e-04
# Epoch 30/50
# 60/60 [==============================] - ETA: 0s - loss: 0.8990 - sparse_categorical_accuracy: 0.6903
# Epoch 30: ReduceLROnPlateau reducing learning rate to 1.0000000474974514e-05.
# 60/60 [==============================] - 21s 351ms/step - loss: 0.8990 - sparse_categorical_accuracy: 0.6903 - val_loss: 1.3329 - val_sparse_categorical_accuracy: 0.5457 - lr: 1.0000e-04
# Epoch 31/50
# 60/60 [==============================] - 21s 353ms/step - loss: 0.8962 - sparse_categorical_accuracy: 0.6911 - val_loss: 1.2754 - val_sparse_categorical_accuracy: 0.5610 - lr: 1.0000e-05
# Epoch 32/50
# 60/60 [==============================] - 21s 353ms/step - loss: 0.8958 - sparse_categorical_accuracy: 0.6915 - val_loss: 1.2729 - val_sparse_categorical_accuracy: 0.5615 - lr: 1.0000e-05
# Epoch 33/50
# 60/60 [==============================] - 21s 352ms/step - loss: 0.8928 - sparse_categorical_accuracy: 0.6921 - val_loss: 1.2710 - val_sparse_categorical_accuracy: 0.5624 - lr: 1.0000e-05
# Epoch 34/50
# 60/60 [==============================] - 21s 346ms/step - loss: 0.8923 - sparse_categorical_accuracy: 0.6925 - val_loss: 1.2704 - val_sparse_categorical_accuracy: 0.5624 - lr: 1.0000e-05
# Epoch 35/50
# 60/60 [==============================] - ETA: 0s - loss: 0.8960 - sparse_categorical_accuracy: 0.6910
# Epoch 35: ReduceLROnPlateau reducing learning rate to 1.0000000656873453e-06.
# 60/60 [==============================] - 21s 347ms/step - loss: 0.8960 - sparse_categorical_accuracy: 0.6910 - val_loss: 1.2691 - val_sparse_categorical_accuracy: 0.5626 - lr: 1.0000e-05
# Epoch 36/50
# 60/60 [==============================] - 21s 347ms/step - loss: 0.8928 - sparse_categorical_accuracy: 0.6920 - val_loss: 1.2697 - val_sparse_categorical_accuracy: 0.5624 - lr: 1.0000e-06
# Epoch 37/50
# 60/60 [==============================] - 21s 353ms/step - loss: 0.8920 - sparse_categorical_accuracy: 0.6927 - val_loss: 1.2703 - val_sparse_categorical_accuracy: 0.5622 - lr: 1.0000e-06
# Epoch 38/50
# 60/60 [==============================] - 21s 352ms/step - loss: 0.8946 - sparse_categorical_accuracy: 0.6917 - val_loss: 1.2705 - val_sparse_categorical_accuracy: 0.5623 - lr: 1.0000e-06
# Epoch 39/50
# 60/60 [==============================] - 21s 347ms/step - loss: 0.8921 - sparse_categorical_accuracy: 0.6926 - val_loss: 1.2705 - val_sparse_categorical_accuracy: 0.5622 - lr: 1.0000e-06
# Epoch 40/50
# 60/60 [==============================] - ETA: 0s - loss: 0.8925 - sparse_categorical_accuracy: 0.6928
# Epoch 40: ReduceLROnPlateau reducing learning rate to 1.0000001111620805e-07.
# 60/60 [==============================] - 21s 346ms/step - loss: 0.8925 - sparse_categorical_accuracy: 0.6928 - val_loss: 1.2710 - val_sparse_categorical_accuracy: 0.5622 - lr: 1.0000e-06
# Epoch 41/50
# 60/60 [==============================] - 21s 352ms/step - loss: 0.8941 - sparse_categorical_accuracy: 0.6919 - val_loss: 1.2707 - val_sparse_categorical_accuracy: 0.5622 - lr: 1.0000e-07
# Epoch 42/50
# 60/60 [==============================] - 21s 349ms/step - loss: 0.8947 - sparse_categorical_accuracy: 0.6915 - val_loss: 1.2707 - val_sparse_categorical_accuracy: 0.5622 - lr: 1.0000e-07
# Epoch 43/50
# 60/60 [==============================] - 21s 353ms/step - loss: 0.8964 - sparse_categorical_accuracy: 0.6906 - val_loss: 1.2709 - val_sparse_categorical_accuracy: 0.5622 - lr: 1.0000e-07
# Epoch 44/50
# 60/60 [==============================] - 21s 353ms/step - loss: 0.8924 - sparse_categorical_accuracy: 0.6925 - val_loss: 1.2706 - val_sparse_categorical_accuracy: 0.5621 - lr: 1.0000e-07
# Epoch 45/50
# 60/60 [==============================] - ETA: 0s - loss: 0.8929 - sparse_categorical_accuracy: 0.6923
# Epoch 45: ReduceLROnPlateau reducing learning rate to 1.000000082740371e-08.
# 60/60 [==============================] - 21s 352ms/step - loss: 0.8929 - sparse_categorical_accuracy: 0.6923 - val_loss: 1.2703 - val_sparse_categorical_accuracy: 0.5623 - lr: 1.0000e-07
# Epoch 46/50
# 60/60 [==============================] - 21s 347ms/step - loss: 0.8914 - sparse_categorical_accuracy: 0.6929 - val_loss: 1.2704 - val_sparse_categorical_accuracy: 0.5623 - lr: 1.0000e-08
# Epoch 47/50
# 60/60 [==============================] - 21s 347ms/step - loss: 0.8932 - sparse_categorical_accuracy: 0.6923 - val_loss: 1.2707 - val_sparse_categorical_accuracy: 0.5622 - lr: 1.0000e-08
# Epoch 48/50
# 60/60 [==============================] - 21s 348ms/step - loss: 0.8928 - sparse_categorical_accuracy: 0.6920 - val_loss: 1.2706 - val_sparse_categorical_accuracy: 0.5622 - lr: 1.0000e-08
# Epoch 49/50
# 60/60 [==============================] - 21s 348ms/step - loss: 0.8907 - sparse_categorical_accuracy: 0.6927 - val_loss: 1.2703 - val_sparse_categorical_accuracy: 0.5622 - lr: 1.0000e-08
# Epoch 50/50
# 60/60 [==============================] - ETA: 0s - loss: 0.8941 - sparse_categorical_accuracy: 0.6920
# Epoch 50: ReduceLROnPlateau reducing learning rate to 1.000000082740371e-09.
# 60/60 [==============================] - 21s 353ms/step - loss: 0.8941 - sparse_categorical_accuracy: 0.6920 - val_loss: 1.2704 - val_sparse_categorical_accuracy: 0.5622 - lr: 1.0000e-08

# %%
process_images(model, 5)
# Out:
# 1/1 [==============================] - 0s 448ms/step
